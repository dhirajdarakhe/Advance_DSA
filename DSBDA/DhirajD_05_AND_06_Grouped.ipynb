# %% [markdown]
# # **Problem statement 5:**

# %% [markdown]
# Perform the following operations on any open-source dataset (e.g., data.csv)
# 1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for a
# dataset (age, income etc.) with numeric variables grouped by one of the qualitative (categorical)
# variable. For example, if your categorical variable is age groups and quantitative variable is
# income, then provide summary statistics of income grouped by the age groups. Create a list that
# contains a numeric value for each response to the categorical variable.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = sns.load_dataset('iris')
df2 = df1.copy()

# %% [markdown]
# # New Section

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df3 = df1.groupby(by='species')

# %%
df3.mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df3.max()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
df3.min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
df3.max()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
df3.std()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          0.352490     0.379064      0.173664     0.105386
# versicolor      0.516171     0.313798      0.469911     0.197753
# virginica       0.635880     0.322497      0.551895     0.274650

# %%
df3.quantile()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
df3.median()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
# Percentile distribution of the 3 species

labels = ['setosa', 'versicolor', 'virginica']
size = df2['species'].value_counts()
plt.pie(size, labels = labels, shadow = False, autopct = '%.2f%%')
plt.title('Iris Species', fontsize = 20)
plt.legend()
plt.show()

# %%
# species				
l  = ["setosa",	"versicolor",	"virginica"	]
size = df2['species'].value_counts()
plt.pie(size, labels=l, shadow=False, autopct='%.02f%%')
plt.title('Iris Species')
plt.show()

# %%
col = df2.select_dtypes(include=['int64', 'float64']).columns.tolist()
for c in col:
   print(f'Column name : {c}')
   print(f'Column mean: {df2[c].mean()}')
# Out:
# Column name : sepal_length
# Column mean %.3d%: 5.843333333333334
# Column name : sepal_width
# Column mean %.3d%: 3.0573333333333337
# Column name : petal_length
# Column mean %.3d%: 3.7580000000000005
# Column name : petal_width
# Column mean %.3d%: 1.1993333333333336
